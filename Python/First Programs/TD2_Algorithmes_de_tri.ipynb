# %% [markdown]
# # Révisions - Planche 2
#
# ## Algorithme de tri en python
#
# Exercice n°1

# %%
def tri_insertion(tab):
    '''Trie le tableau par ordre croissant
    en appliquant l'algorithme de tri par insertion'''
    n = len(tab)
    for i in range(1, n):
        valeur_insertion = tab[i]
        # la variable j sert à déterminer
        # ou placer la valeur à ranger
        j = i
        # tant qu'on a pas trouvé la place de l'élément à
        # insérer on décale les valeurs du tableau vers la droite
        while j > 0 and valeur_insertion < tab[j - 1]:
            tab[j] = tab[j - 1]
            j = j - 1
        tab[j] = valeur_insertion
    return tab

# Exemple:

tab = [98, 12, 104, 23, 131, 9]
tri_insertion(tab)
# Out:
# [9, 12, 23, 98, 104, 131]

# %% [markdown]
# Exercice n°2

# %%
def echange(tab, i, j):
    '''Echange les éléments d'indice i et j dans le tableau tab.'''
    temp = tab[i]
    tab[i] = tab[j]
    tab[j] = temp
    
def tri_insertion(tab):
    '''Trie le tableau tab dans l'ordre croissant
    par la méthode du tri par insertion.'''
    N = len(tab)
    for k in range(N):
        imin = k
        for i in range(imin, N):
            if tab[i] < tab[imin]:
                imin = i
        echange(tab, k, imin)
    return tab
               
tab = [41, 55, 21, 18, 12, 6, 25]
tri_insertion(tab)
# Out:
# [6, 12, 18, 21, 25, 41, 55]

# %% [markdown]
# Exercice n°3

# %%
def echange(tab, i, j):
    '''Echange les éléments d'indice i et j dans le tableau tab.'''
    temp = tab[i]
    tab[i] = tab[j]
    tab[j] = temp

def tri_bulles(tab):
    '''Trie le tableau tab dans l'ordre croissant
    par la méthode du tri à bulles.'''
    n = len(tab)
    for i in range(n):
        for j in range(n):
            if tab[j] > tab[i]:
                echange(tab, j, i)
    return tab
                
tab = [9, 3, 7, 2, 3, 1, 6]
tri_bulles(tab)
# Out:
# [1, 2, 3, 3, 6, 7, 9]
